# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

file_path = 'categorised_data.xlsx'
data = pd.read_excel(file_path)

# %%
data.head(5)
# Out:
#   GenderSelect        Country   Age                    EmploymentStatus  \
# 0          NaN            NaN   NaN                                 NaN
# 1            F              F     F                                   F
# 2      Unknown        Unknown  Mode                             Unknown
# 3   Non-binary            NaN   NaN                  Employed full-time
# 4       Female  United States    30  Not employed, but looking for work
#
#   StudentStatus LearningDataScience CodeWriter CareerSwitcher  \
# 0           NaN                 NaN        NaN            NaN
# 1             F                   F          A              A
# 2            No                  No    Unknown        Unknown
# 3           NaN                 NaN        Yes            NaN
# 4           NaN                 NaN        NaN            NaN
#
#    CurrentJobTitleSelect TitleFit  ... JobFactorExperienceLevel  \
# 0                    NaN      NaN  ...                      NaN
# 1                      A        F  ...                        F
# 2                Unknown     Fine  ...       Somewhat Important
# 3  DBA/Database Engineer     Fine  ...                      NaN
# 4                    NaN      NaN  ...                      NaN
#
#   JobFactorDepartment      JobFactorTitle JobFactorCompanyFunding  \
# 0                 NaN                 NaN                     NaN
# 1                   F                   F                       F
# 2  Somewhat Important  Somewhat Important      Somewhat Important
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#       JobFactorImpact     JobFactorRemote   JobFactorIndustry  \
# 0                 NaN                 NaN                 NaN
# 1                   F                   F                   F
# 2  Somewhat Important  Somewhat Important  Somewhat Important
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#   JobFactorLeaderReputation  JobFactorDiversity JobFactorPublishingOpportunity
# 0                       NaN                 NaN                            NaN
# 1                         F                   F                              F
# 2        Somewhat Important  Somewhat Important             Somewhat Important
# 3                       NaN                 NaN                            NaN
# 4        Somewhat important                 NaN                            NaN
#
# [5 rows x 91 columns]

# %%
category_row = data.iloc[1]
print(category_row)
# Out:
# GenderSelect                      F
# Country                           F
# Age                               F
# EmploymentStatus                  F
# StudentStatus                     F
#                                  ..
# JobFactorRemote                   F
# JobFactorIndustry                 F
# JobFactorLeaderReputation         F
# JobFactorDiversity                F
# JobFactorPublishingOpportunity    F
# Name: 1, Length: 91, dtype: object

# %%
category = category_row.to_dict()

# %%
print(category)
# Out:
# {'GenderSelect': 'F', 'Country': 'F', 'Age': 'F', 'EmploymentStatus': 'F', 'StudentStatus': 'F', 'LearningDataScience': 'F', 'CodeWriter': 'A', 'CareerSwitcher': 'A', 'CurrentJobTitleSelect': 'A', 'TitleFit': 'F', 'CurrentEmployerType': 'A', 'MLToolNextYearSelect': 'A', 'MLMethodNextYearSelect': 'A', 'LanguageRecommendationSelect': 'A', 'PublicDatasetsSelect': 'A', 'LearningPlatformSelect': 'A', 'LearningPlatformUsefulnessArxiv': 'F', 'LearningPlatformUsefulnessBlogs': 'F', 'LearningPlatformUsefulnessCollege': 'F', 'LearningPlatformUsefulnessCompany': 'F', 'LearningPlatformUsefulnessConferences': 'F', 'LearningPlatformUsefulnessFriends': 'F', 'LearningPlatformUsefulnessKaggle': 'F', 'LearningPlatformUsefulnessNewsletters': 'F', 'LearningPlatformUsefulnessCommunities': 'F', 'LearningPlatformUsefulnessDocumentation': 'F', 'LearningPlatformUsefulnessCourses': 'F', 'LearningPlatformUsefulnessProjects': 'F', 'LearningPlatformUsefulnessPodcasts': 'F', 'LearningPlatformUsefulnessSO': 'F', 'LearningPlatformUsefulnessTextbook': 'F', 'LearningPlatformUsefulnessTradeBook': 'F', 'LearningPlatformUsefulnessTutoring': 'F', 'LearningPlatformUsefulnessYouTube': 'F', 'BlogsPodcastsNewslettersSelect': 'A', 'LearningDataScienceTime': 'F', 'CoursePlatformSelect': 'A', 'TimeSpentStudying': 'A', 'DataScienceIdentitySelect': 'F', 'FormalEducation': 'F', 'MajorSelect': 'F', 'Tenure': 'F', 'PastJobTitlesSelect': 'F', 'FirstTrainingSelect': 'FirstTrainingSelect', 'LearningCategorySelftTaught': 'F', 'LearningCategoryOnlineCourses': 'F', 'LearningCategoryWork': 'F', 'LearningCategoryUniversity': 'F', 'LearningCategoryKaggle': 'F', 'LearningCategoryOther': 'F', 'MLSkillsSelect': 'A', 'MLTechniquesSelect': 'A', 'ParentsEducation': 'F', 'EmployerIndustry': 'F', 'EmployerMLTime': 'F', 'EmployerSearchMethod': 'F', 'UniversityImportance': 'F', 'JobFunctionSelect': 'F', 'WorkDataTypeSelect': 'F', 'WorkProductionFrequency': 'F', 'WorkDatasetSize': 'F', 'TimeGatheringData': 'A', 'TimeModelBuilding': 'A', 'TimeProduction': 'A', 'TimeVisualizing': 'A', 'TimeFindingInsights': 'A', 'TimeOtherSelect': 'A', 'AlgorithmUnderstandingLevel': 'F', 'WorkChallengesSelect': 'F', 'WorkDataVisualizations': 'A', 'RemoteWork': 'A', 'CompensationUSD': 'O', 'SalaryChange': 'F', 'JobSatisfaction': 'O', 'JobSearchResource': 'F', 'JobFactorLearning': 'F', 'JobFactorSalary': 'F', 'JobFactorOffice': 'F', 'JobFactorLanguages': 'F', 'JobFactorCommute': 'F', 'JobFactorMagement': 'F', 'JobFactorExperienceLevel': 'F', 'JobFactorDepartment': 'F', 'JobFactorTitle': 'F', 'JobFactorCompanyFunding': 'F', 'JobFactorImpact': 'F', 'JobFactorRemote': 'F', 'JobFactorIndustry': 'F', 'JobFactorLeaderReputation': 'F', 'JobFactorDiversity': 'F', 'JobFactorPublishingOpportunity': 'F'}

# %%
fill_methods = data.iloc[2].to_dict()

# %%
print(fill_methods)
# Out:
# {'GenderSelect': 'Unknown', 'Country': 'Unknown', 'Age': 'Mode', 'EmploymentStatus': 'Unknown', 'StudentStatus': 'No', 'LearningDataScience': 'No', 'CodeWriter': 'Unknown', 'CareerSwitcher': 'Unknown', 'CurrentJobTitleSelect': 'Unknown', 'TitleFit': 'Fine', 'CurrentEmployerType': 'Median', 'MLToolNextYearSelect': 'Median', 'MLMethodNextYearSelect': 'Median', 'LanguageRecommendationSelect': 'Median', 'PublicDatasetsSelect': 'Unknown', 'LearningPlatformSelect': 'Unknown', 'LearningPlatformUsefulnessArxiv': 'Unknown', 'LearningPlatformUsefulnessBlogs': 'Unknown', 'LearningPlatformUsefulnessCollege': 'Unknown', 'LearningPlatformUsefulnessCompany': 'Unknown', 'LearningPlatformUsefulnessConferences': 'Unknown', 'LearningPlatformUsefulnessFriends': 'Unknown', 'LearningPlatformUsefulnessKaggle': 'Unknown', 'LearningPlatformUsefulnessNewsletters': 'Unknown', 'LearningPlatformUsefulnessCommunities': 'Unknown', 'LearningPlatformUsefulnessDocumentation': 'Unknown', 'LearningPlatformUsefulnessCourses': 'Unknown', 'LearningPlatformUsefulnessProjects': 'Unknown', 'LearningPlatformUsefulnessPodcasts': 'Unknown', 'LearningPlatformUsefulnessSO': 'Unknown', 'LearningPlatformUsefulnessTextbook': 'Unknown', 'LearningPlatformUsefulnessTradeBook': 'Unknown', 'LearningPlatformUsefulnessTutoring': 'Unknown', 'LearningPlatformUsefulnessYouTube': 'Unknown', 'BlogsPodcastsNewslettersSelect': 'Unknown', 'LearningDataScienceTime': 'Mode', 'CoursePlatformSelect': 'Unknown', 'TimeSpentStudying': 'Mode', 'DataScienceIdentitySelect': 'Median', 'FormalEducation': 'Median', 'MajorSelect': 'Unknown', 'Tenure': 'Mode', 'PastJobTitlesSelect': 'Unknown', 'FirstTrainingSelect': 'Unknown', 'LearningCategorySelftTaught': 'Mode', 'LearningCategoryOnlineCourses': 'Mode', 'LearningCategoryWork': 'Mode', 'LearningCategoryUniversity': 'Mode', 'LearningCategoryKaggle': 'Mode', 'LearningCategoryOther': 'Mode', 'MLSkillsSelect': 'Unknown', 'MLTechniquesSelect': 'Unknown', 'ParentsEducation': 'Unknown', 'EmployerIndustry': 'Unknown', 'EmployerMLTime': 'Mode', 'EmployerSearchMethod': 'Unknown', 'UniversityImportance': 'Unknown', 'JobFunctionSelect': 'Unknown', 'WorkDataTypeSelect': 'Unknown', 'WorkProductionFrequency': 'Unknown', 'WorkDatasetSize': 'Unknown', 'TimeGatheringData': 'Mode', 'TimeModelBuilding': 'Mode', 'TimeProduction': 'Mode', 'TimeVisualizing': 'Mode', 'TimeFindingInsights': 'Mode', 'TimeOtherSelect': 'Mode', 'AlgorithmUnderstandingLevel': 'Mode', 'WorkChallengesSelect': 'Unknown', 'WorkDataVisualizations': 'Mode', 'RemoteWork': 'Median', 'CompensationUSD': 'Unknown', 'SalaryChange': 'Unknown', 'JobSatisfaction': 'Median', 'JobSearchResource': 'Unknown', 'JobFactorLearning': 'Somewhat Important', 'JobFactorSalary': 'Somewhat Important', 'JobFactorOffice': 'Somewhat Important', 'JobFactorLanguages': 'Somewhat Important', 'JobFactorCommute': 'Somewhat Important', 'JobFactorMagement': 'Somewhat Important', 'JobFactorExperienceLevel': 'Somewhat Important', 'JobFactorDepartment': 'Somewhat Important', 'JobFactorTitle': 'Somewhat Important', 'JobFactorCompanyFunding': 'Somewhat Important', 'JobFactorImpact': 'Somewhat Important', 'JobFactorRemote': 'Somewhat Important', 'JobFactorIndustry': 'Somewhat Important', 'JobFactorLeaderReputation': 'Somewhat Important', 'JobFactorDiversity': 'Somewhat Important', 'JobFactorPublishingOpportunity': 'Somewhat Important'}

# %%
data = data.iloc[3:].reset_index(drop=True)
data.head(5)
# Out:
#   GenderSelect        Country  Age  \
# 0   Non-binary            NaN  NaN
# 1       Female  United States   30
# 2         Male           Cada   28
# 3         Male  United States   56
# 4         Male         Taiwan   38
#
#                                     EmploymentStatus StudentStatus  \
# 0                                 Employed full-time           NaN
# 1                 Not employed, but looking for work           NaN
# 2                 Not employed, but looking for work           NaN
# 3  Independent contractor, freelancer, or self-em...           NaN
# 4                                 Employed full-time           NaN
#
#   LearningDataScience CodeWriter CareerSwitcher  \
# 0                 NaN        Yes            NaN
# 1                 NaN        NaN            NaN
# 2                 NaN        NaN            NaN
# 3                 NaN        Yes            NaN
# 4                 NaN        Yes            NaN
#
#               CurrentJobTitleSelect TitleFit  ... JobFactorExperienceLevel  \
# 0             DBA/Database Engineer     Fine  ...                      NaN
# 1                               NaN      NaN  ...                      NaN
# 2                               NaN      NaN  ...           Very Important
# 3  Operations Research Practitioner   Poorly  ...                      NaN
# 4                Computer Scientist     Fine  ...                      NaN
#
#   JobFactorDepartment  JobFactorTitle JobFactorCompanyFunding JobFactorImpact  \
# 0                 NaN             NaN                     NaN             NaN
# 1                 NaN             NaN                     NaN             NaN
# 2      Very Important  Very Important          Very Important  Very Important
# 3                 NaN             NaN                     NaN             NaN
# 4                 NaN             NaN                     NaN             NaN
#
#   JobFactorRemote JobFactorIndustry JobFactorLeaderReputation  \
# 0             NaN               NaN                       NaN
# 1             NaN               NaN        Somewhat important
# 2  Very Important    Very Important            Very Important
# 3             NaN               NaN                       NaN
# 4             NaN               NaN                       NaN
#
#   JobFactorDiversity JobFactorPublishingOpportunity
# 0                NaN                            NaN
# 1                NaN                            NaN
# 2     Very Important                 Very Important
# 3                NaN                            NaN
# 4                NaN                            NaN
#
# [5 rows x 91 columns]

# %%
# Fill blanks according to specified methods
for column, fill_method in fill_methods.items():
    if fill_method == 'Mode' or data[column].dtype == 'object':
        mode_value = data[column].mode()[0] if not data[column].mode().empty else 'Unknown'
        data[column] = data[column].fillna(mode_value)
    elif fill_method == 'Median':
        if data[column].dtype in ['float64', 'int64']:
            median_value = data[column].median()
            data[column] = data[column].fillna(median_value)
        else:
            mode_value = data[column].mode()[0] if not data[column].mode().empty else 'Unknown'
            data[column] = data[column].fillna(mode_value)
    else:
        data[column] = data[column].fillna(fill_method)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21528\3319320218.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].fillna(mode_value)

# %%
# Check if any blanks remain in the data
remaining_blanks = data.isnull().sum().sum()
if remaining_blanks > 0:
    print(f"There are {remaining_blanks} remaining blanks in the data.")
else:
    print("No blanks remain in the data.")
# Out:
# No blanks remain in the data.

# %%
# Identify numerical and non-numerical columns
numerical_columns = data.select_dtypes(include=[np.number]).columns
non_numerical_columns = data.select_dtypes(exclude=[np.number]).columns

# %%
# Process numerical columns
scaler = StandardScaler()
data[numerical_columns] = scaler.fit_transform(data[numerical_columns].astype(float))

# %%
# Rename numerical columns after scaling
renamed_numerical_columns = {column: f"{column}_{category.get(column, '')}" for column in numerical_columns}
data.rename(columns=renamed_numerical_columns, inplace=True)

# %%
# Initialize an empty DataFrame to store one-hot encoded data for non-numerical columns
one_hot_encoded_data = pd.DataFrame()

# Iterate over each non-numerical column to process them individually
for column in non_numerical_columns:
    # Split entries in the column by comma, expand to new DataFrame, and stack into a single Series
    expanded_data = data[column].str.split(',', expand=True).stack().reset_index(level=1, drop=True)
    # Convert categorical values in the Series to one-hot encoded format and sum the results for each original row index
    expanded_data = pd.get_dummies(expanded_data).groupby(level=0).sum()

    # Retrieve the category suffix for the current column from the category dictionary, default to empty string if not found
    category_suffix = category.get(column, '')
    # Rename the columns of the one-hot encoded DataFrame to include the category suffix
    expanded_data.columns = [f"{column}_{col}_{category_suffix}" for col in expanded_data.columns]
    
    # Concatenate the current one-hot encoded DataFrame to the accumulating DataFrame along columns
    one_hot_encoded_data = pd.concat([one_hot_encoded_data, expanded_data], axis=1)

# %%
# Display the first five columns with 5 rows each from the one_hot_encoded_data DataFrame
print(one_hot_encoded_data.iloc[:, :6].head())
# Out:
#    GenderSelect_A different identity_F  GenderSelect_Female_F  \
# 0                                    0                      0
# 1                                    0                      1
# 2                                    0                      0
# 3                                    0                      0
# 4                                    0                      0
#
#    GenderSelect_Male_F  GenderSelect_Non-binary_F  Country_Argenti_F  \
# 0                    0                          1                  0
# 1                    0                          0                  0
# 2                    1                          0                  0
# 3                    1                          0                  0
# 4                    1                          0                  0
#
#    Country_Australia_F
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
# Concatenate numerical data and one-hot encoded data
final_numerical_columns = renamed_numerical_columns.values()
data = pd.concat([data[list(final_numerical_columns)], one_hot_encoded_data], axis=1)

# %%
processed_data_path = 'processed_data_final.csv'
data.to_csv(processed_data_path, index=False)

processed_data_path
# Out:
# 'processed_data_final.csv'
